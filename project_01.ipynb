# %%
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
from pathlib import Path
# %matplotlib inline

# %%
# Top 10 Cities in the US with the best transporation system
top_filepath = Path("../project-01/top_10_transit.csv")
top_data = pd.read_csv("top_10_transit.csv")
top_data.head()
# Out:
#    Rank                  Name  Score   TCI     Jobs Trips/Week  Routes  \
# 0     1  District of Columbia    9.3  23.3  658,064      8,095      25
# 1     2              New York    6.0  16.2  619,067      6,352      10
# 2     3     Massachusetts, MA    4.4   6.1  156,602      1,728       5
# 3     4          Illinois, IL    4.2   5.9  157,407      1,724       4
# 4     5        California, CA    5.1   5.5  163,744      1,662       6
#
#   Transit Shed %Transit  Population
# 0        50 mi   37.08%     672,391
# 1        27 mi   29.09%  19,798,228
# 2        17 mi   10.00%   6,789,248
# 3        23 mi    9.00%  12,854,526
# 4        27 mi    5.00%  38,982,847

# %%
# US Cities with the best entertainment
most_filepath = Path("../project-01/most_entertainment.csv")
most_data = pd.read_csv("most_entertainment.csv")
most_data.head()
# Out:
#    Overall Rank (1=Most Fun)           City  Total Score  \
# 0                          1  Las Vegas, NV        72.39
# 1                          2    Orlando, FL        64.30
# 2                          3   New York, NY        57.62
# 3                          4      Miami, FL        56.41
# 4                          5    Chicago, IL        55.22
#
#    Entertainment & Recreation Rank  Nightlife & Parties Rank  Costs Rank
# 0                                5                         1          71
# 1                                2                         3          17
# 2                                1                         2         182
# 3                                9                         4         125
# 4                                7                         6         144

# %%
# US Top 4 Cities with Hghest Crime Rate
highest_filepath = Path("../project-01/hightest_crime_rate.csv")
highest_data = pd.read_csv("highest_crime_rate.csv")
highest_data.head()
# Out:
#             State  Combined Rate  Violent  Crime Rate Property Crime Rate
# 0      New Mexico           4276                856.6               3,419
# 1          Alaska           4185                885.0                3300
# 2       Louisiana           3813                537.0                3276
# 3  South Carolina           3500                488.0                3017
# 4        Arkansas           3456                543.0                2913

# %%
# US Median Household Income 2020
median_filepath = Path("../project-01/median_household_income.csv")
median_data = pd.read_csv("median_household_income.csv")
median_data.head()
# Out:
#   Household Income Percentile        2020        2019 Absolute Increase  \
# 0                       1.00%      $0.00       $0.00             $0.00
# 1                       2.00%  $1,400.00     $610.12           $789.88
# 2                       2.00%  $1,400.00     $610.12           $789.88
# 3                       3.00%  $5,000.00   $4,067.48           $932.52
# 4                       4.00%  $8,174.00   $7,118.10         $1,055.90
#
#   Percentage Change
# 0                 0
# 1           129.46%
# 2           129.46%
# 3            22.93%
# 4            14.83%

# %%
# US Best & Worst School Districts
best_filepath = Path("../project-01/best_worst_schools.csv")
best_data = pd.read_csv("best_worst_schools.csv")
best_data.head()
# Out:
#    Overall Rank (1=Best)          State  Total Score  Quality Rank  \
# 0                      1  Massachusetts        71.73             1
# 1                      2    Connecticut        66.25             2
# 2                      3     New Jersey        65.64             3
# 3                      4       Virginia        63.75             3
# 4                      5        Vermont        61.65             8
#
#    Safety Rank
# 0            1
# 1           19
# 2           15
# 3           15
# 4            3

# %%
# US House Price Prediction 2021
real_filepath = Path("../project-01/real_estate.csv")
real_data = pd.read_csv("real_estate.csv")
real_data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df=pd.read_csv("../project-01/real_estate.csv")

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
sns.distplot(df["Y house price of unit area"])
# Out:
# C:\Users\marjo\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(data=df.corr().round(2),annot=True)

# %%
sns.pairplot(df)
